# %%
import sys
sys.path.append("../")
from plotting import CandlePlot
import pandas as pd

# %%
from technicals.patterns import apply_patterns

# %%
df = pd.read_pickle("../data/GBP_JPY_H1.pkl")

# %%
df_an = df[['time', 'mid_o', 'mid_h', 'mid_l', 'mid_c']].copy()

# %%
df_an.tail()
# Out:
#                           time    mid_o    mid_h    mid_l    mid_c
# 3995 2023-04-02 21:00:00+00:00  164.405  164.469  164.313  164.350
# 3996 2023-04-02 22:00:00+00:00  164.357  164.357  163.940  164.074
# 3997 2023-04-02 23:00:00+00:00  164.075  164.100  163.714  163.845
# 3998 2023-04-03 00:00:00+00:00  163.848  163.850  163.456  163.727
# 3999 2023-04-03 01:00:00+00:00  163.723  163.743  163.428  163.674

# %%
df_an = apply_patterns(df_an)

# %%
df_an.tail()
# Out:
#                           time    mid_o    mid_h    mid_l    mid_c  \
# 3995 2023-04-02 21:00:00+00:00  164.405  164.469  164.313  164.350
# 3996 2023-04-02 22:00:00+00:00  164.357  164.357  163.940  164.074
# 3997 2023-04-02 23:00:00+00:00  164.075  164.100  163.714  163.845
# 3998 2023-04-03 00:00:00+00:00  163.848  163.850  163.456  163.727
# 3999 2023-04-03 01:00:00+00:00  163.723  163.743  163.428  163.674
#
#       body_lower  body_upper  body_bottom_perc  body_top_perc  body_perc  ...  \
# 3995     164.350     164.405         23.717949      58.974359  35.256410  ...
# 3996     164.074     164.357         32.134293     100.000000  67.865707  ...
# 3997     163.845     164.075         33.937824      93.523316  59.585492  ...
# 3998     163.727     163.848         68.781726      99.492386  30.710660  ...
# 3999     163.674     163.723         78.095238      93.650794  15.555556  ...
#
#       body_perc_prev_2  HANGING_MAN  SHOOTING_STAR  SPINNING_TOP  MARUBOZU  \
# 3995         74.324324        False          False         False     False
# 3996         14.705882        False          False         False     False
# 3997         35.256410        False          False         False     False
# 3998         67.865707        False          False         False     False
# 3999         59.585492        False          False         False     False
#
#       ENGULFING  TWEEZER_TOP  TWEEZER_BOTTOM  MORNING_STAR  EVENING_STAR
# 3995      False        False           False         False         False
# 3996      False        False           False         False         False
# 3997      False        False           False         False         False
# 3998      False        False           False         False         False
# 3999      False        False           False         False         False
#
# [5 rows x 31 columns]

# %%
import plotly.graph_objects as go

# %%
df_an[df_an.MARUBOZU==True]
# Out:
#                           time    mid_o    mid_h    mid_l    mid_c  \
# 385  2022-09-01 10:00:00+00:00  161.434  161.438  160.988  160.988
# 1004 2022-10-07 05:00:00+00:00  161.772  162.041  161.772  162.039
# 1140 2022-10-16 21:00:00+00:00  166.983  166.983  166.568  166.575
# 1455 2022-11-03 00:00:00+00:00  168.356  168.356  167.883  167.892
# 1584 2022-11-10 10:00:00+00:00  166.430  166.917  166.422  166.916
# 2261 2022-12-20 15:00:00+00:00  160.906  160.906  159.466  159.493
# 3962 2023-03-30 12:00:00+00:00  163.578  164.348  163.576  164.342
#
#       body_lower  body_upper  body_bottom_perc  body_top_perc  body_perc  ...  \
# 385      160.988     161.434          0.000000      99.111111  99.111111  ...
# 1004     161.772     162.039          0.000000      99.256506  99.256506  ...
# 1140     166.575     166.983          1.686747     100.000000  98.313253  ...
# 1455     167.892     168.356          1.902748     100.000000  98.097252  ...
# 1584     166.430     166.916          1.616162      99.797980  98.181818  ...
# 2261     159.493     160.906          1.875000     100.000000  98.125000  ...
# 3962     163.578     164.342          0.259067      99.222798  98.963731  ...
#
#       body_perc_prev_2  HANGING_MAN  SHOOTING_STAR  SPINNING_TOP  MARUBOZU  \
# 385          41.421569        False          False         False      True
# 1004         51.636364        False          False         False      True
# 1140         30.534351        False          False         False      True
# 1455         29.491525        False          False         False      True
# 1584          4.477612        False          False         False      True
# 2261         60.030166        False          False         False      True
# 3962         60.728745        False          False         False      True
#
#       ENGULFING  TWEEZER_TOP  TWEEZER_BOTTOM  MORNING_STAR  EVENING_STAR
# 385       False        False           False         False         False
# 1004       True        False           False         False         False
# 1140       True        False           False         False         False
# 1455      False        False           False         False         False
# 1584       True        False           False         False         False
# 2261       True        False           False         False         False
# 3962       True        False           False         False         False
#
# [7 rows x 31 columns]

# %%
MARKER = '#0066FF'
dfp = df_an.iloc[600:800]
cp = CandlePlot(dfp, candles=True)
df_temp = cp.df_plot[cp.df_plot.MARUBOZU==True]
cp.fig.add_trace(go.Candlestick(
                x=df_temp.sTime,
                open=df_temp.mid_o,
                high=df_temp.mid_h,
                low=df_temp.mid_l,
                close=df_temp.mid_c,
                line=dict(width=1), opacity=1,
                increasing_fillcolor=MARKER,
                decreasing_fillcolor=MARKER,
                increasing_line_color=MARKER,  
                decreasing_line_color=MARKER
            ))

cp.show_plot()
