# %%
import sys
sys.path.append('../')
from plotting import CandlePlot
import pandas as pd

# %%
from technicals.indicators import BollingerBands, ATR, KeltnerChannels, RSI, MACD

# %%
df = pd.read_pickle("../data/AUD_CAD_H1.pkl")

# %%
df_an = df.copy()

# %%
df_an = MACD(df_an)

# %%
df_an.tail()
# Out:
#                           time  volume    mid_o    mid_h    mid_l    mid_c  \
# 3995 2023-04-02 21:00:00+00:00     204  0.90186  0.90333  0.90148  0.90170
# 3996 2023-04-02 22:00:00+00:00    2764  0.90183  0.90286  0.90116  0.90131
# 3997 2023-04-02 23:00:00+00:00    2620  0.90132  0.90150  0.89880  0.89919
# 3998 2023-04-03 00:00:00+00:00    3423  0.89920  0.90112  0.89898  0.90027
# 3999 2023-04-03 01:00:00+00:00    3874  0.90028  0.90258  0.90016  0.90212
#
#         bid_o    bid_h    bid_l    bid_c    ask_o    ask_h    ask_l    ask_c  \
# 3995  0.90147  0.90237  0.90078  0.90135  0.90226  0.90433  0.90186  0.90204
# 3996  0.90150  0.90274  0.90104  0.90118  0.90216  0.90358  0.90125  0.90144
# 3997  0.90118  0.90135  0.89870  0.89908  0.90146  0.90164  0.89891  0.89930
# 3998  0.89911  0.90104  0.89888  0.90016  0.89930  0.90122  0.89908  0.90038
# 3999  0.90016  0.90249  0.90006  0.90203  0.90040  0.90266  0.90027  0.90222
#
#           MACD    SIGNAL      HIST
# 3995 -0.001117 -0.000636 -0.000481
# 3996 -0.001313 -0.000771 -0.000542
# 3997 -0.001621 -0.000941 -0.000680
# 3998 -0.001758 -0.001105 -0.000653
# 3999 -0.001698 -0.001223 -0.000474

# %%
dfp = df_an.iloc[-100:]
cp = CandlePlot(dfp, candles=True)
cp.show_plot(line_traces=[], sec_traces=[])

# %%
import plotly.graph_objects as go

# %%
cp = CandlePlot(dfp, candles=False)
cp.fig.add_trace(go.Bar(
    x=cp.df_plot.sTime,
    y=cp.df_plot.HIST,
    name="HIST"
))
cp.show_plot(line_traces=['SIGNAL', 'MACD'], sec_traces=[])
